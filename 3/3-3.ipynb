# %%
pA=0.8

# %%
pB=0.7

# %%
pC=0.9

# %%
#x+x+2*x=1

# %%
x=1/4

# %%
1/4*2
# Out:
# 0.5

# %%
P=1/4*0.8+1/4*0.7+1/2*0.9
P
# Out:
# 0.825

# %%
A=1/4*0.8/P
A
# Out:
# 0.24242424242424246

# %%
B=1/4*0.7/P
B
# Out:
# 0.21212121212121213

# %%
C=1/2*0.9/P
C
# Out:
# 0.5454545454545455

# %%
A+B+C
# Out:
# 1.0
