# %%
p1=0.9

# %%
p2=0.8

# %%
p3=0.6

# %%
pA=1/3*0.9 + 1/3*0.8 + 1/3*0.6
pA
# Out:
# 0.7666666666666666

# %%
p1=1/3*0.9/pA
p1
# Out:
# 0.391304347826087

# %%
p2=1/3*0.8/pA
p2
# Out:
# 0.3478260869565218

# %%
p3=1/3*0.6/pA
p3
# Out:
# 0.2608695652173913

# %%
p1+p2+p3
# Out:
# 1.0
