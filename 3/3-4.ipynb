# %%
0.1*0.2*0.25
# Out:
# 0.005000000000000001

# %%
0.9*0.2*0.25+0.8*0.1*0.25+0.75*0.1*0.2
# Out:
# 0.08

# %%
1-0.9*0.8*0.75
# Out:
# 0.45999999999999996

# %%
1-0.9*0.8*0.75-0.1*0.2*0.25
# Out:
# 0.45499999999999996
