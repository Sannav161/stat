# %% [markdown]
# Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept)

# %%
import numpy as np

# %%
X = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
X
# Out:
# array([ 35,  45, 190, 200,  40,  70,  54, 150, 120, 110])

# %%
y = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
y
# Out:
# array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
def mse_(B1, y=y, X=X, n=10): #без интерсепта
    return np.sum((B1*X-y)**2)/n

# %%
B1=0.1

# %%
n=10

# %%
alpha=1e-6
alpha
# Out:
# 1e-06

# %%
for i in range (10000):
    B1 -=alpha*(2/n)*np.sum((B1*X-y)*X)
    if i%5000==0:
        print('interetion: {i}, B1={B1}, mse={mse}'.format(i=i,B1=B1, mse=mse_(B1)))
# Out:
# interetion: 0, B1=0.25952808, mse=493237.7212546963
# interetion: 5000, B1=5.889820420132673, mse=56516.85841571943
